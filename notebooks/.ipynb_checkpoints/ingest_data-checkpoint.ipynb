# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_csv("../data/soft4.csv")

# %%
d = raw[(raw['yourfeed']==0) & ((raw['experiment_id']==6667)| (raw['experiment_id']==6669))]

# %%
seedling = []
for i,r in d.iterrows():
    los=r['loopOrder'].split(",")[:-1]
    if len(los)>1:
        for i,lo in enumerate(los):
            col = "{}_response".format(int(lo.replace("e",""))+1)
            dat = (r['rid'], lo.replace("e",""), r[col], i+1, ("Android" in r['Browser_Operating System']) | ("iPhone" in r['Browser_Operating System']), r['experiment_id'])
            seedling.append(dat)
bpd = pd.DataFrame(seedling, columns =["rid","item","response","order", "is_mobile", "experiment_id"])
bpd['response'] = (bpd['response']=="Share").astype(int) 
bpd['dwell'] = -1 #.groupby("rid").mean()
bpd['condition'] =0
bpd['completed'] =0 #pull in embedded data in future interations
bpd
# Out:
#                                        rid item  response  order  is_mobile  \
# 0     60638b94-0ab4-cbed-8380-3162d6e6ab88   27         0      1      False
# 1     60638b94-0ab4-cbed-8380-3162d6e6ab88   50         0      2      False
# 2     60638b94-0ab4-cbed-8380-3162d6e6ab88   94         0      3      False
# 3     60638b94-0ab4-cbed-8380-3162d6e6ab88   60         0      4      False
# 4     60638b94-0ab4-cbed-8380-3162d6e6ab88   67         0      5      False
# 5     60638b94-0ab4-cbed-8380-3162d6e6ab88   61         0      6      False
# 6     60638b94-0ab4-cbed-8380-3162d6e6ab88  132         0      7      False
# 7     60638b94-0ab4-cbed-8380-3162d6e6ab88   30         0      8      False
# 8     60638b94-0ab4-cbed-8380-3162d6e6ab88   52         0      9      False
# 9     60638b94-0ab4-cbed-8380-3162d6e6ab88  129         0     10      False
# 10    60638b94-0ab4-cbed-8380-3162d6e6ab88   98         0     11      False
# ...

# %%
import sys
sys.path.append("..")
from utils import dump_data, render_data, fx
from creds import qualtrics_token
import pandas as pd
import psycopg2
from datetime import datetime
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import re
# %matplotlib inline  
import time
from creds import rds_url, rds_port, rds_db, rds_username, rds_password, user, password
import pandas as pd
import pandas.io.sql as sqlio

# %%
#dbug = pd.read_csv("../data/debugR.csv")
#demo_dat[demo_dat['value'].str.contains(('|'.join(dingos)))].sort_values("user_id")

# %%
conn = psycopg2.connect(
    host=rds_url,
    port=rds_port,
    dbname=rds_db,
    user=rds_username,
    password=rds_password)

# %%
demo_dat = sqlio.read_sql_query("select * from demographics where experiment_id='6669' or experiment_id='6667'", conn)

# %%
user_id2rid = demo_dat[demo_dat['field']=='rid'][['value','user_id', 'user_agent', 'experiment_id']]
#user_id2rid[user_id2rid.duplicated(keep=False)] #must check
user_id2rid.columns = ['rid','user_id', 'user_agent', 'experiment_id']
user_id2rid = user_id2rid[~user_id2rid.duplicated()]
order_data = demo_dat[demo_dat['field']=='order'][['value','user_id']]
order_data = order_data[~order_data.duplicated(['user_id'])]
response=[]
for i,r in order_data.iterrows():
    for i,item in enumerate(r['value'].split(",")):
        response.append((i+1, item,r['user_id']))
response = pd.DataFrame(response, columns = ['order','item','user_id'])
yourfeed = pd.merge(response, user_id2rid, on='user_id', how='left')

s = (yourfeed.groupby('rid')['user_id'].nunique() > 1) #why??
mrid = s[s].index.values
yourfeed = yourfeed[~yourfeed['rid'].isin(mrid)]

# %%
mrid
# Out:
# array(['60638b72-585b-f615-82ff-ba2bc39660ee',
#        '60638d6f-7501-1395-80b5-2610a0819af7',
#        '60647a30-aa0f-78a3-16a7-90f9211875c4'], dtype=object)

# %%
stim_dat = sqlio.read_sql_query("select * from stimulus where (experiment_id='6667' or experiment_id='6669') and stim != 'introCard[dwell]'", conn)
stim_dat['item'] =stim_dat['stim'].apply(lambda x:x.replace("[dwell]","").replace("card",""))
stim_dat['dwell'] = stim_dat['stim'].str.contains("dwell")
dwells =  stim_dat[stim_dat['dwell']]
dwells['dwell'] = dwells['response'].astype(int)
dwells = dwells[~dwells.duplicated(subset=['user_id',"item"])]
#dwells[dwells.duplicated(subset=['user_id',"item"])].groupby(['user_id',"item"]).agg({"dwell" : np.var}) #check!

yourfeed= pd.merge(yourfeed,dwells[['user_id','item' ,'dwell']], on=['user_id','item'], how='left')
# Out:
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
s = stim_dat[~stim_dat['dwell']]
s = s[~s.duplicated(subset=['user_id',"item"])]
yourfeed = pd.merge(yourfeed,s[['user_id','item','response']], on =['user_id',"item"], how='left')
yourfeed['response'] = yourfeed['response'].fillna("-1").astype(int)+1
yourfeed['condition']= 1

# %%
did_dwell = demo_dat[demo_dat['field']=='did_dwell']
did_dwell = did_dwell[~did_dwell.duplicated(subset=['user_id'])]
did_dwell['completed'] = 1
yourfeed = pd.merge(yourfeed,did_dwell[['user_id','field']], on =['user_id'], how='left')

# %%
yourfeed['is_mobile'] = yourfeed['user_agent'].str.contains("Android") | yourfeed['user_agent'].str.contains("iPhone")

# %%
long = pd.concat([yourfeed[['rid', 'item', 'response', 'order', 'dwell', 'condition', 'is_mobile', 'experiment_id','completed']],bpd])
# Out:
# ---------------------------------------------------------------------
# KeyError                            Traceback (most recent call last)
# <ipython-input-585-de118a98d7dc> in <module>()
# ----> 1 long = pd.concat([yourfeed[['rid', 'item', 'response', 'order', 'dwell', 'condition', 'is_mobile', 'experiment_id']],bpd])
#
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
# ...

# %%
demos = raw[['rid', 'crt_ages', 'crt_printer', 'crt_bread', 'crt_race','crt_sheep','pk1','pk2','pk3','pk4','pk5','age','gender','education','income','ethnicity','demrep_c', 'social_media_check', 'facebook_frequency', 'media1', 'media2',       'newsfeed_knowledge', 'accuracy_imp']]
out = pd.merge(long,demos,on='rid',how='left')

# %%
out.to_csv("../data/soft_long.csv")

# %%
demo_dat = sqlio.read_sql_query("select * from demographics where experiment_id='6669'", conn)
stim_dat = sqlio.read_sql_query("select * from stimulus where experiment_id='6669' and stim != 'introCard[dwell]'", conn)
stim_dat['item'] =stim_dat['stim'].apply(lambda x:x.replace("[dwell]","").replace("card",""))
stim_dat['dwell'] = stim_dat['stim'].str.contains("dwell")

#stim_dat[stim_dat['dwell']].groupby('user_id').count()
demo_dat[demo_dat['field']=='did_dwell'].shape
# Out:
# (32, 8)

# %%
a = demo_dat[demo_dat['field']=='rid'][['user_id', 'value']]
b = stim_dat[stim_dat['dwell']].groupby('user_id').count().reset_index()[['user_id','dwell']]
c = demo_dat[demo_dat['field']=='did_dwell'][['user_id', 'value']]

# %%
d = pd.merge(a,b,on='user_id',how='left')
e = pd.merge(d,c,on='user_id',how='left')
out = e[~e.duplicated("user_id")]
out.columns = ['user_id', 'rid', 'num_dwells', "finished"]
out['num_dwells'] = out['num_dwells'].fillna(0)
out['finished'] = out['finished'].map(lambda x:1-pd.isna(x))
out.to_csv("../data/6669_rids.csv")
# Out:
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(set(c['user_id'].values))
# Out:
# 27

# %%
demo_dat = sqlio.read_sql_query("select * from demographics where experiment_id='66667'", conn)

# %%
ridz= demo_dat[demo_dat['field']=='rid'][['user_id','session_id','value']]

# %%
set(ridz['value'])
# Out:
# {'605268c5-28fa-1c42-2287-f8ad766bbd96',
#  '60526907-94ae-edd2-4410-e03914fcf02a',
#  '60526929-c4e6-40f8-8a0d-cc181926d884',
#  '60527027-a7e0-c435-28ef-fe73287b69e6',
#  '6052735d-846d-9b75-5402-f37c3df73c9c',
#  '605273b2-c237-a786-4893-83194c51488b',
#  '6052740f-1004-4c39-ceb9-24ab0aafb686'}

# %%
dy = d[d['yourfeed']==1]
set(ridz['value']).intersection(dy['rid'])
# Out:
# {'605268c5-28fa-1c42-2287-f8ad766bbd96',
#  '60526907-94ae-edd2-4410-e03914fcf02a',
#  '60526929-c4e6-40f8-8a0d-cc181926d884',
#  '60527027-a7e0-c435-28ef-fe73287b69e6',
#  '6052735d-846d-9b75-5402-f37c3df73c9c',
#  '605273b2-c237-a786-4893-83194c51488b',
#  '6052740f-1004-4c39-ceb9-24ab0aafb686'}

# %%
dy['rid']
# Out:
# 1     60526907-94ae-edd2-4410-e03914fcf02a
# 2     605268c5-28fa-1c42-2287-f8ad766bbd96
# 5     60526929-c4e6-40f8-8a0d-cc181926d884
# 7     60527027-a7e0-c435-28ef-fe73287b69e6
# 12    605273b2-c237-a786-4893-83194c51488b
# 13    6052740f-1004-4c39-ceb9-24ab0aafb686
# 14    6052735d-846d-9b75-5402-f37c3df73c9c
# 20    60526908-6e63-1eb6-762b-bd93ba0e9821
# Name: rid, dtype: object

# %%
yourfeed_data = pd.merge(s,ridz, how='left',on=['user_id','session_id'])
yourfeed_data['rid']=yourfeed_data['value']
yd = pd.read_csv("../data/yourfeed_pilot_v3.csv")

set(yd['rid']).intersection(set(yourfeed_data['rid']))
# pd.merge(yourfeed_data, yd, how='left',on=['rid'])
# Out:
# {'6044ed1e-9e07-ed2e-fd1a-f2187fbb7d35',
#  '6044ed26-b27f-4e6b-cec3-131f5f2fd05a',
#  '6044ed55-ff57-2c0b-3e2c-c7bb089af43e'}

# %%
yd = pd.read_csv("../data/yourfeed_pilot_v3_March 17, 2021_08.31.csv")

#pd.merge(yourfeed_data, yd, how='left',on=['rid'])

# %%
demo_dat = sqlio.read_sql_query("select * from demographics", conn)

# %%
set(yourfeed_data['rid'].values).intersection(demo_dat['rid'])
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rid'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                Traceback (most recent call last)
# ...

# %%
stim_dat = sqlio.read_sql_query("select * from stimulus where experiment_id='5123' and stim != 'introCard[dwell]'", conn)
stim_dat['dwell'] = stim_dat['stim'].str.contains("dwell")
s = stim_dat[~stim_dat['dwell']]
s['sum']=1
s.groupby('user_id').sum()
# Out:
# -------------------------------------------------------
# OperationalError      Traceback (most recent call last)
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1377             else:
# -> 1378                 cur.execute(*args)
#    1379             return cur
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError        Traceback (most recent call last)
# /usr/local/Cellar/python3/3.6.4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1381             try:
# -> 1382                 self.con.rollback()
#    1383             except Exception:  # pragma: no cover
#
# ...

# %%
demo_dat = sqlio.read_sql_query("select * from demographics where experiment_id='5123'", conn)
ridz= demo_dat[demo_dat['field']=='rid'][['user_id','session_id','value']]
yourfeed_data = pd.merge(s,ridz, how='left',on=['user_id','session_id'])
yourfeed_data['rid']=yourfeed_data['value']
yd = pd.read_csv("../data/yourfeed_pilot_v3.csv")

pd.merge(yourfeed_data, yd, how='left',on=['rid'])
# Out:
#                    time_stamp         user_id        session_id  \
# 0  2021-02-17 04:09:32.265505   12.222.97.130  8160A9E774EDAC5D
# 1  2021-02-17 04:09:34.503547   12.222.97.130  8160A9E774EDAC5D
# 2  2021-02-18 03:07:26.314043   99.174.248.86  5CD447938187D488
# 3  2021-02-18 03:07:31.225576   99.174.248.86  5CD447938187D488
# 4  2021-02-18 03:07:35.435700   99.174.248.86  5CD447938187D488
# 5  2021-02-18 03:07:46.160283   99.174.248.86  5CD447938187D488
# 6  2021-02-18 03:07:53.881833   99.174.248.86  5CD447938187D488
# 7  2021-02-18 03:08:16.764376   99.174.248.86  5CD447938187D488
# 8  2021-02-18 03:08:26.551306   99.174.248.86  5CD447938187D488
# 9  2021-02-18 03:08:29.639609   99.174.248.86  5CD447938187D488
# 10 2021-02-18 03:08:36.206823   99.174.248.86  5CD447938187D488
# 11 2021-02-18 03:08:37.915127   99.174.248.86  5CD447938187D488
# 12 2021-02-18 03:08:48.758707   99.174.248.86  5CD447938187D488
# 13 2021-02-18 03:08:56.976079   99.174.248.86  5CD447938187D488
# ...

# %%
raw = pd.read_csv("../data/soft4.csv")
d = raw[(raw['yourfeed']==1) & (raw['experiment_id']==6669)]
seedling = []
for i,r in d.iterrows():
    los=r['loopOrder'].split(",")[:-1]
    if len(los)>1:
        for i,lo in enumerate(los):
            col = "{}_response".format(int(lo.replace("e",""))+1)
            dat = (r['rid'], lo.replace("e",""), r[col], i+1, ("Android" in r['Browser_Operating System']) | ("iPhone" in r['Browser_Operating System']), r['experiment_id'])
            seedling.append(dat)
bpd = pd.DataFrame(seedling, columns =["rid","item","response","order", "is_mobile", "experiment_id"])
bpd['response'] = (bpd['response']=='Share').astype(int)
bpd['dwell'] = -1 #.groupby("rid").mean()
bpd['condition'] =0
print(bpd.groupby(['rid']).count().shape)
print(d.shape)
# Out:
# (0, 7)
# (66, 227)

# %%
bpd['response'].hist()
# Out:
# <AxesSubplot:>

# %%
d
# Out:
#         StartDate       EndDate  Status IPAddress  Progress  \
# 434  4/1/21 18:57  4/1/21 19:02       0   *******       100
# 437  4/1/21 18:59  4/1/21 19:03       0   *******       100
# 438  4/1/21 18:55  4/1/21 19:05       0   *******       100
# 439  4/1/21 18:56  4/1/21 19:05       0   *******       100
# 448  4/1/21 19:20  4/1/21 19:23       0   *******       100
# 466  4/1/21 19:20  4/1/21 19:28       0   *******       100
# 475  4/1/21 19:24  4/1/21 19:30       0   *******       100
# 480  4/1/21 19:24  4/1/21 19:31       0   *******       100
# 482  4/1/21 19:28  4/1/21 19:31       0   *******       100
# 487  4/1/21 19:27  4/1/21 19:31       0   *******       100
# 488  4/1/21 19:29  4/1/21 19:32       0   *******       100
# 495  4/1/21 19:29  4/1/21 19:33       0   *******       100
# 497  4/1/21 19:22  4/1/21 19:33       0   *******       100
# 511  4/1/21 19:32  4/1/21 19:35       0   *******       100
# 513  4/1/21 19:25  4/1/21 19:36       0   *******       100
# ...

# %%
demo_dat = sqlio.read_sql_query("select * from demographics where experiment_id='6669'", conn)
len(set(demo_dat[demo_dat['field'] =='did_dwell']['user_id'].values))
# Out:
# 27

# %%
demo_dat['field']
# Out:
# 0      did_dwell
# 1            rid
# 2      did_dwell
# 3            rid
# 4          order
# 5            rid
# 6          order
# 7      did_dwell
# 8            rid
# 9          order
# 10     did_dwell
# 11     did_dwell
# 12           rid
# 13         order
# 14           rid
# 15           rid
# 16         order
# 17           rid
# 18         order
# 19           rid
# 20     did_dwell
# 21           rid
# 22         order
# 23         order
# 24           rid
# 25         order
# 26     did_dwell
# 27           rid
# 28         order
# 29           rid
#          ...
# 126        order
# 127          rid
# 128          rid
# 129        order
# 130          rid
# 131        order
# 132    did_dwell
# 133    did_dwell
# 134        order
# 135          rid
# 136        order
# 137          rid
# 138        order
# 139          rid
# 140        order
# 141          rid
# 142        order
# 143    did_dwell
# 144    did_dwell
# 145          rid
# 146        order
# ...
